# %%
#How to Display a Matplotlib RGB Image: https://www.pyimagesearch.com/2014/11/03/display-matplotlib-rgb-image/
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = cv2.imread('./img/000000.png', cv2.IMREAD_UNCHANGED)
print(img.shape)
# print(img)
# Out:
# (370, 1224, 3)

# %%
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img, cmap='gray')
plt.show()

# %%
(b, g, r) = img[20, 100] #[y,x]
(b,g,r)
# Out:
# (252, 185, 92)

# %%
img1 = mpimg.imread('./img/000001.png')
# print(img)

# %%
imgplot = plt.imshow(img1, cmap='gray')
plt.show()
